# %% [markdown]
# Stage One: Import Libraries / Data
# This is a CSV file that I found that I believed would work well for this project. Here I am importing the file from Kaggle.
# First I have imported pandas as a means to manipulate and organize the data. This has been imported as pd instead of pandas to expidite future use of pandas without having to spell it out. The code is then reading in the chosen csv file and printing a section of the output to demonstrate it is working.

# %%
import pandas as pd

#create a dataframe object from a csv
student_df = pd.read_csv('student-por.csv', delimiter=",")

student_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# Stage Two: Display a Summary and Sub-sections of the Data.
# (Show at least three different views using filtering or value sorting, and describe your choices)
# The first block of code is displaying a 10 row subsection of the data set organized by the arbitrary assignment value from the original file structure.
# The Second block of code shows the age range and average age of the students used in this data set to better understand the population of the data set.
# The Third block of code Demonstrates the range and the mean of the number of absences in the data set and reveals a very large range with a reasonable mean, indicating reasonable overall absences and at least one student that sufferred some significant issue leading to a great numeber of absences.
# The forth block is a random sampling of twenty students from the data set to get an idea of what the average student profile looks like in this data set.

# %%
student_df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# ...

# %%
print(student_df['age'].min())
print(student_df['age'].mean())
print(student_df['age'].max())
# Out:
# 15
# 16.7442218798151
# 22

# %%
print(student_df['absences'].min())
print(student_df['absences'].mean())
print(student_df['absences'].max())
# Out:
# 0
# 3.6594761171032357
# 32

# %%
student_df.sample(20)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 481     MS   F   17       R     GT3       T     2     1   at_home     other
# 89      GP   M   16       U     LE3       A     4     4   teacher    health
# 449     MS   F   15       R     GT3       T     1     2     other  services
# 539     MS   F   16       U     LE3       T     4     1     other     other
# 472     MS   F   16       R     LE3       T     2     2     other     other
# 610     MS   F   19       R     GT3       A     1     1   at_home   at_home
# 389     GP   F   18       U     LE3       T     2     2     other     other
# 416     GP   M   17       U     LE3       A     3     2     other     other
# 113     GP   M   15       U     LE3       T     4     2   teacher     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 640     MS   M   18       R     GT3       T     4     2     other     other
# ...

# %% [markdown]
# Stage Three: Clean Your Data¶
# (Varies by dataset: you might replace missing values with a filler, replace shorthand from the dataset with readable language, and/or delete duplicates)
# I kind of shot myself in the foot on this step as I chose a dataset with a usability score of 10 off of Kaggle because I did not want to run into problem based on my file choice like I have done in earlier assignments. I decided to replace famrel with FamRelationship as I thought famrel was somewhat ambigious. I am not sure what I have done wrong in this section. It appears to be working within the block of code, but when I print out a sample of the file famrel remains. Is it because this function is only suited to continous strings? Maybe I need to created another step that rewrites the file? Not sure.

# %%
contents = student_df
inside = 0
text = 'FamRelationship'

for char in contents:
    if char == 'famrel':
        inside = 1
    elif (inside == 1 and char == 'famrel'):
        inside = 0
    elif inside== 1:
        continue
    else: 
        text += char

print(text[0: 500])
# Out:
# FamRelationshipschoolsexageaddressfamsizePstatusMeduFeduMjobFjobreasonguardiantraveltimestudytimefailuresschoolsupfamsuppaidactivitiesnurseryhigherinternetromantic

# %% [markdown]
# Stage Four: Plot Your Data¶
# (Try at least three different plots - bar, hist, box, area, scatter, hexbin, and pie are all worth viewing - and describe your choices)
# The first graph that I chose was a bargraph. I chose this graph to visualize number of absences per student in relation to one another. This could identify both trends and outliers for interventions and policy changes.
# The second graph I chose was an area graph. I did this because it demonstrates the amounts of each age group, but also provides easily comparable groupings of student age if one were inclined to compare stats across the multiple ages.
# The third graph is a simple pie chart use to visualize family size around the metric of over or under 3 members. I thought this type of comparison of parts of the whole is well represented in a pie graph, but I am not sure how to identify which percentage belongs to over and which belongs to under.

# %%
student_df['absences'].value_counts()[:19].plot(kind="barh", title="Number of absences")
# Out:
# <AxesSubplot:title={'center':'Number of absences'}>

# %%
student_df['age'].value_counts()[:20].plot(kind="area", title="Age of Students")
# Out:
# <AxesSubplot:title={'center':'Age of Students'}>

# %%
#I am not sure which section represents over and which is under and I am not sure how I go about representing that clearly
student_df['famsize'].value_counts()[:20].plot(kind="pie", title="Family Size: Over/Under 3")
# Out:
# <AxesSubplot:title={'center':'Family Size: Over/Under 3'}, ylabel='famsize'>

# %% [markdown]
# Stage Five: Draw Comparisons and Make Claims
# (Think of all the methods we've used so far - what might you analyze about this dataset? This section can mostly be commentary drawing on what you've found so far)
#
# This data set has so many oppotunities for analysis I don't even know where to begin. There are 32 catagories in this set of data and a large number of them can be cross referenced with any other catagory and provide insight the couldbe useful in exposing and addressing issues in the student population. For example, the sections that I chose to adress in this coding exercise include age, family relationship, absences, and family size. Combining the results from any two of these catagories could potentially yield useful information. In this set any of them combined with absences could be particularly useful. If, for instance, we discover that the vast majority of our high absence students are 18 and above we could then follow and see why they have been absent. If patterns are found measures can be taken to mitigate those absences. This can cascade out to exponential opportunities on this dataset because we are not limited to combining two categories, nor are we limitied to analyzing just one set. For example, we could look at absences according to age, then according to age and gender, then according to age and family relationship, and any mix and match of the 32 catagories available that we think may provide useful information. This can then be further manipulated with functions of subsections of the individual categories themselves. For example, printing out the top ten highest counts in the absence catagory and then running analyses across all other categroies for just those ten students and searching for patterns and trends that may be present in those data. This is likely to show us things we already suspect, such as students that have health issues tend to have more absences, but when we discover that students in romatic relationships have a disproportionate amount of absences compared to their single counterparts the data can also lead to more questions that require new approached to data analysis.
